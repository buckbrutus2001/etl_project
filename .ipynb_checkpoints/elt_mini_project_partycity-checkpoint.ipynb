# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.partycity.com/search?q=zombie+costumes&lang=en_US/'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <!--[if lt IE 7]> <html class="ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]> <html class="ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]> <html class="ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
#   <script type="text/javascript">
#    //uncomment and change this to false if you're having trouble with WOFFs
# //var woffEnabled = true;
# //to place your webfonts in a custom directory
# //uncomment this and set it to where your webfonts are.
# var customPath = "https://www.partycity.com/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581";
#   </script>
#   <title>
#    Search Results | Party City
#   </title>
#   <link href="/on/demandware.static/Sites-partycity_us2-Site/-/default/dw86e2563b/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/on/demandware.static/Sites-partycity_us2-Site/-/default/dwaa82cb42/images/favicon.png" rel="shortcut icon"/>
#   <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/js/rapid.min.js">
#   </script>
#   <script>
#    Yo.configure('https://qoe-1.yottaa.net/api/v1/configure.rapid.js?key=PxtuJdFySOWAeg');
#   </script>
#   <script async="" src="//www.increasingly.co/Implementation/amR6xE/js/Increasingly_amR6xE.js" type="text/javascript">
#   </script>
#   <meta content="" name="description">
#    <meta content="" name="keywords">
#     <!--[if lt IE 9]>
# <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/js/lib/html5.js"></script>
# <![endif]-->
#     <!--[if lte IE 8]>
# <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/lib/jquery/jquery-1.11.1.min.js" type="text/javascript"></script>
# <![endif]-->
#     <script type="text/javascript">
#      //<!--
# /* <![CDATA[ (head-active_data.js) */
# var dw = (window.dw || {});
# dw.ac = {
#     _analytics: null,
#     _events: [],
#     _category: "",
#     _capture: function(configs) {
#         if (Object.prototype.toString.call(configs) === "[object Array]") {
#             configs.forEach(captureObject);
#             return;
#         }
#         dw.ac._events.push(configs);
#     },
# 	capture: function() {
# 		dw.ac._capture(arguments);
# 		// send to CQ as well:
# 		if (window.CQuotient) {
# 			window.CQuotient.trackEventsFromAC(arguments);
# 		}
# 	},
#     EV_PRD_SEARCHHIT: "searchhit",
#     EV_PRD_DETAIL: "detail",
#     EV_PRD_RECOMMENDATION: "recommendation",
#     EV_PRD_SETPRODUCT: "setproduct",
#     applyContext: function(context) {
#         if (typeof context === "object" && context.hasOwnProperty("category")) {
#         	dw.ac._category = context.category;
#         }
#     },
#     setDWAnalytics: function(analytics) {
#         dw.ac._analytics = analytics;
#     }
# };
# /* ]]> */
# // -->
#     </script>
#     <script type="text/javascript">
#      //<!--
# /* <![CDATA[ (head-cquotient.js) */
# var CQuotient = window.CQuotient = {};
# CQuotient.clientId = 'bbrq-partycity_us2';
# CQuotient.realm = 'BBRQ';
# CQuotient.siteId = 'partycity_us2';
# CQuotient.instanceType = 'prd';
# CQuotient.activities = [];
# CQuotient.cqcid='';
# CQuotient.cquid='';
# CQuotient.initFromCookies = function () {
# 	var ca = document.cookie.split(';');
# 	for(var i=0;i < ca.length;i++) {
# 	  var c = ca[i];
# 	  while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 	  if (c.indexOf('cqcid=') == 0) {
# 		  CQuotient.cqcid=c.substring('cqcid='.length,c.length);
# 	  } else if (c.indexOf('cquid=') == 0) {
# 		  CQuotient.cquid=c.substring('cquid='.length,c.length);
# 		  break;
# 	  }
# 	}
# }
# CQuotient.getCQCookieId = function () {
# 	if(window.CQuotient.cqcid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqcid;
# };
# CQuotient.getCQUserId = function () {
# 	if(window.CQuotient.cquid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cquid;
# };
# CQuotient.trackEventsFromAC = function (/* Object or Array */ events) {
# try {
# 	if (Object.prototype.toString.call(events) === "[object Array]") {
# 		events.forEach(_trackASingleCQEvent);
# 	} else {
# 		CQuotient._trackASingleCQEvent(events);
# 	}
# } catch(err) {}
# };
# CQuotient._trackASingleCQEvent = function ( /* Object */ event) {
# 	if (event && event.id) {
# 		if (event.type === dw.ac.EV_PRD_DETAIL) {
# 			CQuotient.trackViewProduct( {id:'', alt_id: event.id, type: 'raw_sku'} );
# 		} // not handling the other dw.ac.* events currently
# 	}
# };
# CQuotient.trackViewProduct = function(/* Object */ cqParamData){
# 	var cq_params = {};
# 	cq_params.cookieId = CQuotient.getCQCookieId();
# 	cq_params.userId = CQuotient.getCQUserId();
# 	cq_params.product = cqParamData.product;
# 	cq_params.realm = cqParamData.realm;
# 	cq_params.siteId = cqParamData.siteId;
# 	cq_params.instanceType = cqParamData.instanceType;
#
# 	if(CQuotient.sendActivity) {
# 		CQuotient.sendActivity(CQuotient.clientId, 'viewProduct', cq_params);
# 	} else {
# 		CQuotient.activities.push({activityType: 'viewProduct', parameters: cq_params});
# 	}
# };
# /* ]]> */
# // -->
#     </script>
#     <script>
#      console.log('Load custom styling: ');
#     </script>
#     <link href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/plp.css" rel="stylesheet"/>
#     <link href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/o_expanded-menu.css" rel="stylesheet"/>
#     <noscript>
#      <link href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/o_expanded-menu.css" rel="stylesheet"/>
#     </noscript>
#     <link as="style" href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/o_dw-footer.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#     <noscript>
#      <link href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/o_dw-footer.css" rel="stylesheet"/>
#     </noscript>
#     <link as="style" href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/print.css" media="print" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#     <noscript>
#      <link href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/print.css" rel="stylesheet"/>
#     </noscript>
#     <!--[if lte IE 8]>
# <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.js" type="text/javascript"></script>
# <script src="https://cdn.rawgit.com/chuckcarpenter/REM-unit-polyfill/master/js/rem.min.js" type="text/javascript"></script>
# <![endif]-->
#     <meta content="Party City" name="author"/>
#     <meta content="app-id=854035336" name="apple-itunes-app"/>
#     <meta content="app-id=com.partycity" name="google-play-app"/>
#     <meta content="App" name="msApplication-ID">
#      <meta content="https://s7d5.scene7.com/is/image/PartyCity/PC%20final" name="msapplication-TileImage">
#       <noscript>
#        <link href="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/jquery.smartbanner.css" rel="stylesheet" type="text/css"/>
#       </noscript>
#       <meta content="DkOTkqepGSyiF6L7ivbA4sojuA9AEIGHwUFYfwkD9y0" name="google-site-verification">
#        <meta content="2228A82030D522B86BC639152C6C7279" name="msvalidate.01">
#         <script type="text/javascript">
#          var tyche = { mode: 'tyche', config: '//config.playwire.com/1023196/v2/websites/71167/banner.json' };
#         </script>
#         <script defer="" id="tyche" src="//cdn.intergi.com/hera/tyche.js" type="text/javascript">
#         </script>
#         <script>
#          var CRL8_SITENAME = 'partycity-t8muwq';
# !function(){var e=window.crl8=window.crl8||{},n=!1,i=[];e.ready=function(e)
# {n?e():i.push(e)}
# ,e.pixel=e.pixel||function()
# {e.pixel.q.push(arguments)}
# ,e.pixel.q=e.pixel.q||[];var t=window.document,o=t.createElement("script"),c=e.debug||-1!==t.location.search.indexOf("crl8-debug=true")?"js":"min.js";o.src=t.location.protocol+"//cdn.curalate.com/sites/"+CRL8_SITENAME+"/site/latest/site."+c,o.onload=function(){n=!0,i.forEach(function(e)
# {e()}
# )};var r=t.getElementsByTagName("script")[0];r.parentNode.insertBefore(o,r.nextSibling)}();
#         </script>
#         <meta content="noindex" name="robots"/>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div class="wrapper">
#    <header class="o_main-header light">
#     <section class="row one-column width-container-width height-three-by-one height-mobile-three-by-one padding-bottom-none padding-top-none margin-bottom-none margin-top-none border-bottom-0 border-top-0" data-content-id="34198" data-placement="6">
#      <div class="o_custom-code-block" id="block-34198-1--1-">
#       <style>
#        .o_modal > .block .o_rich-text-block a {
#     color: #000;
#     text-decoration: underline;
#     transition: color 0.3s ease-in;
# }
#
# .o_modal > .block .o_rich-text-block a:hover {
#     color: rgba(48,180,87,1);
# }
#
# img.aria-hidden[data-src],
# img.aria-hidden[data-srcset]{
#     height:0px !important;
#     visibility: hidden !important;
# }
#
# div.a_modal-bg.overlay-dark, div.a_modal-overlay{
#     z-index:14;
# }
#
# div.o_icon-list a, div.o_icon-list div.o_image-block{
#     flex-basis:25%;
# }
#
# .o_promo-bar div>ul li{
#     font-family:'FuturaPT-Heavy','futura-pt','Futura',Arial;
# }
#
# .IE-11 block-26741-1--1- div.m_accordion-list>ul li{
#     flex-basis:auto;
#     width:50%:
# }
#
# @media all and (min-width:64em) {
# .IE-11 block-26741-1--1- div.m_accordion-list>ul li{
#     flex-basis:auto;
#     width:100%:
# }
# }
#
# div.o_carousel-block .slick-initialized .slick-slide{
#     display:block;
# }
#
# section.height-three-by-one div.o_call-to-action div.block{
#     position:relative;
# }
#
# @media all and (min-width: 600px){
#     section.height-three-by-one div.o_call-to-action div.block{
#         position:absolute;
#     }
#
#     .o_promo-bar .desktop{
#         opacity:1 !important;
#     }
# }
#
# @media all and (max-width: 600px){
#     section.height-three-by-one div.o_call-to-action:before{
#         content:none;
#     }
# }
#
# div.o_category-list-block ul li{
#   margin:0px;
#   padding:1em;
# }
#
# div.o_category-list-block ul li.m_curalate-placeholder {
# 	padding: 0px;
# 	margin: 1em 1em 0px 1em;
# }
#
# .o_carousel-block div.o_image-block{
#     padding:0px;
# }
#
# @media all and (min-width: 1600px) {
#   section.width-full-width div.o_call-to-action div.block,
#   section.width-full-width div.o_carousel-block div.block {
#     max-width: 100%;
#   }
#   section.width-full-width.one-column aside.o_modal h1 {
#     font-size: 3em;
#     margin: auto;
#   }
#   section.width-full-width.one-column aside.o_modal h2 {
#     font-size: 2.6em;
#   }
#   section.width-full-width.one-column aside.o_modal h3 {
#     font-size: 2.4em;
#   }
#   section.width-full-width.one-column div.o_call-to-action h1,
#   section.width-full-width.one-column div.o_carousel-block h1 {
#     font-size: calc(8em + 2vw);
#     margin: auto;
#   }
#   section.width-full-width.one-column div.o_call-to-action h2,
#   section.width-full-width.one-column div.o_carousel-block h2 {
#     font-size: calc(7em + 2vw);
#   }
#   section.width-full-width.one-column div.o_call-to-action h3,
#   section.width-full-width.one-column div.o_carousel-block h3 {
#     font-size: calc(6em + 1.5vw);
#   }
#   section.width-full-width.one-column div.o_call-to-action *[class*='button-style-'][class*='inline'],
#   section.width-full-width.one-column div.o_carousel-block *[class*='button-style-'][class*='inline'] {
#     font-size: 0.8w;
#   }
# }
#
# .o_carousel-block.o_video-block {
#     overflow: hidden;
#     height:100%;
# }
#
# .o_carousel-block div.o_image-block,
# .o_carousel-block a {
#     display:none;
# }
#
# .o_carousel-block div.o_image-block:first-child{
#     display:block;
# }
#
# .o_carousel-block div.slick-initialized div.o_image-block,
# .o_carousel-block div.slick-initialized a{
#     display:block;
# }
#
# button.a_close {
# 	position: absolute;
# 	/*top: 12em;*/
# 	right: 2em;
# 	bottom: auto;
# 	left: auto;
# 	height: 3em;
# 	width: 3em;
# 	overflow: hidden;
# 	text-indent: -9999px;
# 	cursor: pointer;
# }
#
# @media all and (min-width:700px) {
#         button.a_close {
#              top:3em;
#         }
# }
#
# button.a_close:after, button.a_close:before {
#         content:"";
#         display:block;
# 	height: 3em;
# 	width: .5em;
# 	background-color: #97a1aa;
# 	position: absolute;
# 	top: 50%;
# 	right: auto;
# 	bottom: auto;
# 	left: 50%;
# 	-webkit-transform: translateX(-50%) translateY(-50%) rotate(45deg);
# 	transform: translateX(-50%) translateY(-50%) rotate(45deg);
# }
#
# button.a_close:after {
# 	-webkit-transform: translateX(-50%) translateY(-50%) rotate(-45deg);
# 	transform: translateX(-50%) translateY(-50%) rotate(-45deg);
# }
#       </style>
#      </div>
#     </section>
#     <section class="row one-column width-container-width height-three-by-one height-mobile-three-by-one padding-bottom-none padding-top-none margin-bottom-none margin-top-none border-bottom-0 border-top-0" data-content-id="33814" data-placement="6">
#      <div class="o_custom-code-block" id="block-33814-1--1-">
#       <div class="feedback-box" style="display:none;">
#        <img alt="Feedback Button" src="https://www.partycity.com/on/demandware.static/-/Library-Sites-partycity-shared-content2/default/dwcb035743/svg/Feedback.svg" title="Feedback Button"/>
#       </div>
#       <div class="modal-feedback-box" style="display: none;">
#        <div class="modal-content-feedback-box">
#         <span class="close-feedback-box">
#          ×
#         </span>
#         <div class="img-content option-btn-list">
#          <div class="selection-btn-feedback" id="customer-feedback">
#           Customer Service
#          </div>
#          <div class="selection-btn-feedback" id="web-quest-btn">
#           Website Feedback
#          </div>
#         </div>
#         <div class="img-content" id="web-quest-list" style="display:none">
#          <h3>
#           How do you like our site?
#          </h3>
#          <div>
#           <ul class="choice-feedback-box">
#            <li>
#             <div id="improve-feedback-box">
#              Needs Improvement
#             </div>
#            </li>
#            <li>
#            </li>
#            <li>
#            </li>
#            <li>
#            </li>
#            <li>
#             <div id="love-feedback-box">
#              Love it!
#             </div>
#            </li>
#           </ul>
#          </div>
#          <div class="feed-box">
#           <label>
#            Please tell us how we can improve it:
#           </label>
#           <div id="error-message">
#            Please fill the following box.
#           </div>
#           <textarea id="user-feedback"></textarea>
#          </div>
#          <div class="feed-box" style="margin-top:30px;">
#           <div>
#            <label>
#             Can we contact you about your experience?
#            </label>
#            <span>
#             <input class="feed-btn" name="contact" type="radio" value="0"/>
#             Yes
#            </span>
#            <span>
#             <input class="feed-btn" name="contact" type="radio" value="1"/>
#             No
#            </span>
#           </div>
#           <div id="error-message-email">
#            Invalid Email Format
#           </div>
#           <div class="feedback-client-info">
#            <div>
#             Email:
#            </div>
#            <input id="user-email-feedback" type="email"/>
#           </div>
#          </div>
#          <div class="submit-btn-feedback-box">
#           Submit
#          </div>
#          <p>
#           Sorry, but we can't respond to individual comments.
#          </p>
#          <p style="margin-bottom:5px;">
#           If you need immediate assistance, please contact
#           <a href="https://www.partycity.com/contact-us" target="_blank">
#            Customer Care
#           </a>
#           .
#          </p>
#         </div>
#        </div>
#       </div>
#       <script>
#        var imgLoad = {
# 	_modal:null,
# 	_span: null,
# 	_choice: 0,
# 	_click:false,
# 	_replayURL: "",
# 	_gotLink: true,
#         _email: false,
#         _csFeed: false,
# 	_init: function() {
# 		this._modal = document.getElementsByClassName("modal-feedback-box")[0];
# 		this._span = document.getElementsByClassName("close-feedback-box")[0];
# 		this.addListener();
#
#                 var prTextField = document.getElementById("pr-auryctestfield-input");
#                 (function(elm) {
#                 var prReplay = window.setInterval(function(){
#                     if(prTextField != null) {
#                         var Auryclink = elm._replayURL || elm.fallbackURL()
#                         if(Auryclink!= "auryc is not available") {
#                             var aurycSession = elm._replayURL || elm.fallbackURL();
#                             var currentURL = window.location.href + '&pr_auryctestfield='+ encodeURIComponent(aurycSession);
#                             window.history.pushState({path:currentURL}, '', currentURL);
#                             clearInterval(prReplay);
#                         } else {
#                              prTextField = document.getElementById("pr-auryctestfield-input");
#                         }
#                     } else {
#                          prTextField = document.getElementById("pr-auryctestfield-input");
#                     }
#                 }, 100);
#                 })(this);
# 	},
#
# 	getReplay: function() {
# 		if(window.auryc && window.auryc.getReplayUrl ){
# 			(function(elm) {
# 				window.auryc.getReplayUrl(function(replayUrl) {
# 					elm._replayURL = replayUrl;
# 					elm._gotLink = false;
# 				});
# 			})(this);
# 		} else if(this._gotLink) {
# 			setInterval(this.getReplay(), 1000);
# 		}
# 	},
# 	fallbackURL: function() {
#                 if (window.auryc && window.auryc.getSessionMetadata) {
#                         var sessid = window.auryc.getSessionMetadata().sessionId;
#                         var siteid =  window.auryc.getSessionMetadata().siteId;
#                         var url = "https://portal.auryc.com/auth/replay/playback?q=" + siteid + ":" + sessid + "&utm_source=integration&utm_medium=fb";
#                         return url;
#                  } else {
#                          return "auryc is not available";
#                  }
#         },
#
# 	addListener: function() {
#                 var _formList = document.getElementById("web-quest-btn");
#                 var custFeed = document.getElementById("customer-feedback");
#                 if(custFeed) {
#                         (function(elm) {
#                             custFeed.onclick = function() {
#                                     this.parentNode.style.display = "none";
#                                     elm._csFeed = true;
#                                     document.getElementById("web-quest-list").style.display = "block";
#                             }
#                         })(this);
#                 }
#                 if(_formList) {
#                         _formList.onclick = function() {
#                                 this.parentNode.style.display = "none";
#                                 document.getElementById("web-quest-list").style.display = "block";
#                         }
#                 }
#
#
# 		(function(elm) {
#                         var _btnContact = document.querySelectorAll("input[name='contact']");
#                         for(var btnCount = 0; btnCount < _btnContact.length; btnCount++) {
#                                 _btnContact[btnCount].onclick = function(event) {
#                                         if(this.value == 0) {
#                                                 elm._email = true;
#                                         } else {
#                                                 elm._email = false;
#                                         }
#                                 }
#                         }
#
# 			window.onclick = function(event) {
# 				if(event.target == elm._modal) {
# 					elm._modal.style.display = "none";
# 				}
# 			}
# 			elm._span.onclick = function() {
# 				elm._modal.style.display = "none";
# 			}
# 			document.querySelector("div[class='feedback-box']").onclick = function() {
# 				elm._modal.style.display = "block";
# 				try {
# 					elm.getReplay();
# 				} catch (e) {
# 					console.log(e);
# 				}
# 				return false;
# 			}
# 			document.querySelector("div.submit-btn-feedback-box").onclick = function(e) {
# 				var info = document.getElementById('user-feedback').value,
#                                 userEmail = document.getElementById('user-email-feedback').value;
#                                 var _department = 8;
#                                 if(elm._csFeed) {
#                                     info =  info;
#                                     _department = 6;
#                                 }
#                                 if((userEmail.length == 0 || !(userEmail.indexOf('@') > -1))) {
#                                         document.getElementById('error-message-email').style.display = "block";
#                                         return false;
#                                 }
#                                 if(info.length == 0) {
#                                         document.getElementById('error-message').style.display = "block";
#                                         return false;
#                                 }
#                                 e.preventDefault();
# 				$.ajax({
# 					url: "https://feedback-partycity.hhcctech.com/",
# 					type: "POST",
# 					data: {
# 						register:true,
# 						feedback:{
# 							scale:elm._choice+1,
# 							feedback:info,
# 							url_link:window.location.href,
# 							device:navigator.userAgent,
# 							user_email: userEmail,
# 							replay_url: elm._replayURL || elm.fallbackURL(),
#                                                         department: _department
# 						}
# 					},
# 					success: function (data, textStatus, jQxhr) {
# 						document.querySelector('#web-quest-list').innerHTML = "<h3>Thank you</h3> <p style='font-size: 18px;'>We'll use this information to improve our site and keep the party going!</p>";
# 						document.querySelector('.modal-content-feedback-box').className = document.querySelector('.modal-content-feedback-box').className + " thank-you-mess-feed";
# 						window.setTimeout(function() {
# 							elm._modal.style.display = "none";
# 							elm._gotLink = false;
# 						},2000);
# 					}
# 				});
# 				return false;
# 			};
# 		})(this);
#
# 		var btnSelect = document.querySelectorAll('.choice-feedback-box li');
# 		if(btnSelect) {
# 			for(var t = 0; t < btnSelect.length; t++) {
# 				(function(ind,elm,btn) {
# 					btnSelect[t].onclick = function() {
# 						var _active = document.querySelectorAll('.choice-feedback-box li.active');
# 						if(_active ) {
# 							for(var p = 0; p < _active.length; p++) {
# 								_active[p].className = "";
# 							}
# 						}
# 						for(var r = 0; r < ind; r++) {
# 							btn[r].className = 'active';
# 						}
# 						this.className = 'active';
# 						elm._choice = ind;
# 						elm._click = true;
# 					};
# 					btnSelect[t].onmouseover = function() {
# 						if(elm._click == false) {
# 							var _active = document.querySelectorAll('.choice-feedback-box li.active');
# 							if(_active ) {
# 								for(var p = 0; p < _active.length; p++) {
# 									_active[p].className = "";
# 								}
# 							}
# 							for(var r = 0; r < ind; r++) {
# 								btn[r].className = 'active';
# 							}
# 							this.className = 'active';
# 						}
# 					}
# 					btnSelect[t].onmouseout = function() {
# 						var _active = document.querySelectorAll('.choice-feedback-box li.active');
# 						if(_active && !elm._click) {
# 							for(var p = 0; p < _active.length; p++) {
# 								_active[p].className = "";
# 							}
# 						}
# 					}
# 				})(t,this,btnSelect);
# 			}
# 		}
# 	}
# }
# document.addEventListener("DOMContentLoaded", function(){
#     imgLoad._init();
# });
#       </script>
#       <style>
#        .feedback-box {
#                                 display: none;
#                                 position: fixed;
#                                 background-color: transparent;
#                                 font-weight: 700;
#                                 border: 0;
#                                 font-size: 14px;
#                                 font-family: Arial;
#                                 opacity: 1;
#                                 z-index: 9;
#                                 cursor: pointer;
#                                 text-decoration: none;
#                                 -webkit-backface-visibility: hidden;
#                                 backface-visibility: hidden;
#                                 transition: all .5s ease;
#                                 -moz-transition: all .5s ease;
#                                 -webkit-transition: all .5s ease;
#                                 -o-transition: all .5s ease;
#                 width: 37px;
#                 height: 140px;
#                                 right: 4px;
#                                 padding: 0;
#                                 top: 407px;
#                                 color: #000000;
#                                 text-transform: uppercase;
#                 }
#         .feedback-box img{
#               max-width: 100%;
#               max-height: 100%;
#               height: 100%;
#         }
#                 .feedback-box:hover {
#                         -ms-transform: scale(1.02) translateX(-5px);
#                                 -webkit-transform: translateX(-5px);
#                                 -moz-transform: translateX(-5px);
#                 }
#                 /* The Modal (background) */
#                 .modal-feedback-box {
#                                 display: none; /* Hidden by default */
#                                 position: fixed; /* Stay in place */
#                                 z-index: 400; /* Sit on top */
#                                 left: 0;
#                                 top: 0;
#                                 width: 100%; /* Full width */
#                                 height: 100%; /* Full height */
#                                 overflow: auto; /* Enable scroll if needed */
#                                 background-color: #f4f4f4; /* Fallback color */
#                                 background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#                 }
#
#                 /* Modal Content/Box */
#                 .modal-content-feedback-box {
#                                 background-color: #fefefe;
#                                 margin: auto; /* 15% from the top and centered */
#                                 width: 500px; /* Could be more or less, depending on screen size */
#                                 top:0;
#                                 right: 0;
#                                 left: 0;
#                                 bottom:0;
#                                 max-height:620px;
#                                 overflow:hidden;
#                                 position:absolute;
#                                 max-width: 1000px;
#                 }
#                 .option-btn-list {
#     position: relative;
#     top: 40%;
#     bottom: 0;
#     right: 0;
#     left: 0;
#     margin: auto;
# }
#
# .feed-btn {
#     width: 1.2em !important;
#     height: 1.2em !important;
#     margin: 0 10px 0 20px;
# }
#
# .selection-btn-feedback {
#     float: none !important;
#     display: block;
#     margin: 10px auto !important;
#         letter-spacing: 2px;
# }
#                 .img-content {
#                                 width: 90%;
#                                 margin:auto;
#                 }
#
#                 .img-content ul {
#                                 margin:0;
#                                 padding:0;
#                 }
#                 .img-content li {
#                                 display: inline-block;
#                                 float:left;
#                                 margin:5px 0 35px;
#                                 width: 20%;
#                                 min-width:80px;
#                                 height:80px;
#                                 text-align:center;
#                                 background:url(https://partycity1.scene7.com/is/image/PartyCity/full-star-no-rating-01?wid=40&fmt=png) no-repeat;
#                                 background-size:40px;
#                                 position:relative;
#                                 background-position:center top;
#                                 cursor:pointer;
#                 }
#
#                 .img-content li:first-child.active,
#                 .img-content li:first-child:hover {
#                                 background:url(https://partycity.scene7.com/is/image/PartyCity/full-star-rating_feedback-star-1?fmt=png) no-repeat;
#                                 background-size:40px;
#                                 background-position:center top;
#                 }
#
#                 .img-content li:nth-child(2).active,
#                 .img-content li:nth-child(2):hover {
#                                 background:url(https://partycity.scene7.com/is/image/PartyCity/full-star-rating_feedback-star-2?fmt=png) no-repeat;
#                                 background-size:40px;
#                                 background-position:center top;
#                 }
#
#                 .img-content li:nth-child(3).active,
#                 .img-content li:nth-child(3):hover {
#                                 background:url(https://partycity.scene7.com/is/image/PartyCity/full-star-rating_feedback-star-3?fmt=png) no-repeat;
#                                 background-size:40px;
#                                 background-position:center top;
#                 }
#
#                 .img-content li:nth-child(4).active,
#                 .img-content li:nth-child(4):hover {
#                                 background:url(https://partycity.scene7.com/is/image/PartyCity/full-star-rating_feedback-star-4?fmt=png) no-repeat;
#                                 background-size:40px;
#                                 background-position:center top;
#                 }
#
#                 .img-content li:nth-child(5).active,
#                 .img-content li:nth-child(5):hover {
#                                 background:url(https://partycity.scene7.com/is/image/PartyCity/full-star-rating_feedback-star-5?fmt=png) no-repeat;
#                                 background-size:40px;
#                                 background-position:center top;
#                 }
#
#                 .img-content li div {
#                                 margin-bottom: 5px;
#                                 cursor:pointer;
#                                 position:absolute;
#                                 bottom:0;
#                                 width: 70px;
#                                 left: 0;
#                                 right: 0;
#                                 margin:auto;
#                 }
#
#                 .img-content textarea {
#                                 width: 100%;
#                                 margin: auto;
#                                 display: block;
#                                 height: 100px;
#                                 font-size:14px;
#                                 font-family: 'FuturaPT-Book';
#                 }
#                 .selection-btn-feedback,
#                 .submit-btn-feedback-box {
#                                 width: 180px;
#                                 text-align: center;
#                                 border: 1px solid;
#                                 padding: 14px 0;
#                                 text-transform: uppercase;
#                                 font-weight: bold;
#                                 font-size:13px;
#                                 margin: 5px 0 15px;
#                                 float: right;
#                                 background:#000000;
#                                 color:#ffffff;
#                                 cursor:pointer;
#                                 font-family: 'FuturaPT-Medium';
#                 }
#
#                 /* The Close Button */
#                 .modal-content-feedback-box > .close-feedback-box {
#                                 color: #aaa;
#                                 float: right;
#                                 font-size: 28px;
#                                 font-weight: bold;
#                                 margin: 10px 15px;
#                 }
#
#                 .modal-content-feedback-box > .close-feedback-box:hover,
#                 .modal-content-feedback-box > .close-feedback-box:focus {
#                                 color: black;
#                                 text-decoration: none;
#                                 cursor: pointer;
#                 }
#
#                 .img-content div {
#                                 overflow:hidden;
#                                 clear:both;
#                 }
#                 img-content {
#                                 color: #000000;
#                 }
#                 .img-content h3 {
#                                 font-size: 30px;
#                                 font-weight:bold;
#                                 margin:50px 0 20px;
#                 }
#                 #improve-feedback-box {
#                                 font-size:13px;
#                                 font-family: 'FuturaPT-Book';
#                 }
#
#                 #love-feedback-box {
#                                 font-size: 15px;
#                                 bottom:15px;
#                                 width:100%;
#                                 font-family: 'FuturaPT-Book';
#                 }
#                 .img-content p {
#                                 font-size: 13px;
#                                 clear:both;
#                                 margin:0;
#                 }
#                 .feed-box {
#                                 overflow:hidden;
#                                 clear:both;
#                 }
#
#                 .feed-box:nth-child(2) {
#                                 margin:25px 0 0;
#                 }
#
#                 .img-content label {
#                                 font-size: 15px;
#                 }
#                 .thank-you-mess-feed {
#                                 height: 250px;
#                                 width: 430px;
#                 }
#
#                 .feedback-client-info {
#                                 margin:10px 0;
#                                 font-size:15px;
#                 }
#                 .feedback-client-info div{
#                                 width: 10%;
#                                 float:left;
#                                 display:inline-block;
#                                 margin-right:3%;
#                                 padding: 5px 0;
#                                 font-size:15px;
#                                 font-family: 'futuraPT-medium';
#                 }
#
#                 .feedback-client-info input {
#                                 width: 87%;
#                                 padding: 5px;
#                                 font-size:15px;
#                                 border: 1px solid #e0e0e0;
#                                 height: 2.3em;
#                 }
# .feed-box #error-message,
# .feed-box #error-message-email {
#     display:none;
#     padding: 10px 0;
#     font-size: 1.2em;
#     color: #ff0000;
# }
#                 @media screen and (max-width: 700px) {
#                                 .modal-content-feedback-box {
#                                                 width: 100%;
#                                                 max-height: 100%;
#                                                 overflow:auto;
#                                 }
#                                 .img-content li {
#                                                 min-width:auto;
#                                 }
#                                 .feedback-box {
#                                                 font-weight: 600;
#                                                 font-size: 13px;
#                         width: 30px;
#                         height: 116px;
#             top: 378px;
#                                 }
#
#                 }
#
#
# html.no-touchevents .feedback-box,
# html.touchevents .feedback-box{
#     display:block !important;
# }
#       </style>
#      </div>
#     </section>
#     <section class="row one-column width-full-width height-three-by-one height-mobile-three-by-one padding-bottom-none padding-top-none margin-bottom-none margin-top-none border-bottom-0 border-top-0" data-content-id="88721" data-placement="6">
#      <section class="o_promo-bar overlay-dark font-color-light text-align-left height-slim">
#       <div>
#        <ul>
#         <li class="mobile">
#          <strong>
#           20% Off Halloween In Store and Online
#          </strong>
#          <br/>
#         </li>
#        </ul>
#       </div>
#      </section>
#     </section>
#    </header>
#   </div>
#  </body>
# </html>
# PLUS Free Shipping
# <a data-modal="block-block-88721-1--1-promo-modal-1" href="    https://www.partycity.com/coupons" title="Details: Details">
#  <strong>
#   Details
#  </strong>
# </a>
# <li class="desktop">
#  <strong>
#   20% Off Halloween
#  </strong>
#  In Store and Online PLUS Free Shipping
# </li>
# <a data-modal="block-block-88721-1--1-promo-modal-2" href="    https://www.partycity.com/coupons" title="Details: Details">
#  <strong>
#   Details
#  </strong>
# </a>
# <aside class="o_modal" id="block-block-88721-1--1-promo-modal-1" role="dialog">
#  <button class="a_close">
#   Close
#  </button>
#  <div class="block">
#   <section class="row one-column width-container-width height-three-by-one height-mobile-same-as-desktop padding-bottom-none padding-top-none margin-bottom-none margin-top-none border-bottom-0 border-top-0" data-content-id="88716">
#    <div class="o_rich-text-block position-middle-center" id="block-88716-1--1-">
#     <h3 class="text-center" data-children-count="0">
#      In Store and Online
#     </h3>
#     <h3 class="text-center" data-children-count="0">
#      20% Off Halloween
#     </h3>
#     <h3 class="text-center">
#      PLUS
#     </h3>
#     <h3 class="text-center">
#      Free Shipping No Minimum
#     </h3>
#     <h3 class="text-center">
#      Online Code: SCARE20
#     </h3>
#     <h3 class="text-center">
#      <a href="/swo-coupon-landing-page-3.html" target="_blank">
#       GET COUPON
#      </a>
#     </h3>
#    </div>
#   </section>
#   <section class="row one-column width-container-width height-three-by-one height-mobile-three-by-one padding-bottom-normal padding-top-normal margin-bottom-normal margin-top-normal border-bottom-0 border-top-0 e-swo-details" data-content-id="88716">
#    <div class="o_rich-text-block position-middle-center" id="block-88716-2--1-">
#     <p>
#      LIMITED TIME ONLY. Valid coupon code must be entered at checkout to receive discount. Merchandise subtotal is used to calculate discount offer threshold for online promo codes. Discount offer threshold must be met before the discount is applied. Discount applies to merchandise only and does not apply to shipping, fees, taxes, or other non-merchandise charges. Sale, clearance, was/now, promotional items and personalized favor setup fees do not count towards the discount offer threshold. The minimum merchandise subtotal that must be met for shipping promotions is calculated after any discount coupons have been applied. Offer not valid on Helium Tanks, Pre-orders, Balloons, and Toys. Offer may not be combined with other coupon codes. Not valid for prior purchases. Shipping offers are not valid for over-sized, hazardous items, Alaska/Hawaii or military address deliveries. No cash or credit back. We reserve the right to cancel any order due to unauthorized, altered, or ineligible use of discount. All promotional dates &amp; times are subject to change without notice. Only one coupon or promotional code permitted per order and customer. Pricing, participation, selection and availability may vary by store or online. SCARE20 offer valid Friday 10/11/19 at 12:01 AM PT through Tuesday 10/15/19 at 8:59 PM PT.
#     </p>
#    </div>
#   </section>
#  </div>
# </aside>
# <aside class="o_modal" id="block-block-88721-1--1-promo-modal-2" role="dialog">
#  <button class="a_close">
#   Close
#  </button>
#  <div class="block">
#   <section class="row one-column width-container-width height-three-by-one height-mobile-same-as-desktop padding-bottom-none padding-top-none margin-bottom-none margin-top-none border-bottom-0 border-top-0" data-content-id="88716">
#    <div class="o_rich-text-block position-middle-center" id="block-88716-1--1-">
#     <h3 class="text-center" data-children-count="0">
#      In Store and Online
#     </h3>
#     <h3 class="text-center" data-children-count="0">
#      20% Off Halloween
#     </h3>
#     <h3 class="text-center">
#      PLUS
#     </h3>
#     <h3 class="text-center">
#      Free Shipping No Minimum
#     </h3>
#     <h3 class="text-center">
#      Online Code: SCARE20
#     </h3>
#     <h3 class="text-center">
#      <a href="/swo-coupon-landing-page-3.html" target="_blank">
#       GET COUPON
#      </a>
#     </h3>
#    </div>
#   </section>
#   <section class="row one-column width-container-width height-three-by-one height-mobile-three-by-one padding-bottom-normal padding-top-normal margin-bottom-normal margin-top-normal border-bottom-0 border-top-0 e-swo-details" data-content-id="88716">
#    <div class="o_rich-text-block position-middle-center" id="block-88716-2--1-">
#     <p>
#      LIMITED TIME ONLY. Valid coupon code must be entered at checkout to receive discount. Merchandise subtotal is used to calculate discount offer threshold for online promo codes. Discount offer threshold must be met before the discount is applied. Discount applies to merchandise only and does not apply to shipping, fees, taxes, or other non-merchandise charges. Sale, clearance, was/now, promotional items and personalized favor setup fees do not count towards the discount offer threshold. The minimum merchandise subtotal that must be met for shipping promotions is calculated after any discount coupons have been applied. Offer not valid on Helium Tanks, Pre-orders, Balloons, and Toys. Offer may not be combined with other coupon codes. Not valid for prior purchases. Shipping offers are not valid for over-sized, hazardous items, Alaska/Hawaii or military address deliveries. No cash or credit back. We reserve the right to cancel any order due to unauthorized, altered, or ineligible use of discount. All promotional dates &amp; times are subject to change without notice. Only one coupon or promotional code permitted per order and customer. Pricing, participation, selection and availability may vary by store or online. SCARE20 offer valid Friday 10/11/19 at 12:01 AM PT through Tuesday 10/15/19 at 8:59 PM PT.
#     </p>
#    </div>
#   </section>
#  </div>
# </aside>
# <div class="a_modal-bg overlay-dark">
# </div>
# <section class="m_utility-navigation desktop light">
#  <ul>
#   <li>
#    <div class="menu-slot">
#     <section class="row one-column width-container-width height-three-by-one height-mobile-three-by-one padding-bottom-none padding-top-none margin-bottom-none margin-top-none border-bottom-0 border-top-0 sub-swo" data-content-id="88094" data-placement="6">
#      <div class="o_custom-code-block" id="block-88094-1--1-">
#       <div class="scroll bopis-utility-menu us-subswo" style="display:none;">
#        <div class="sub-swo-banner-wrapper">
#         <div class="sub-swo-banner-desktop">
#          <span class="sub-swo-main" style="font-size: 1.4em;">
#           Serve up snacks &amp; screams!
#          </span>
#          <a class="details-button-22 sub-swo-cta" href="https://www.partycity.com/halloween-decorations" rel="nofollow">
#           Shop Halloween Décor
#          </a>
#         </div>
#         <a class="sub-swo-banner-mobile" href="https://www.partycity.com/halloween-decorations" rel="nofollow">
#          <span class="sub-swo-main" style="font-size: 1.2em;">
#           Serve up snacks &amp; screams!
#          </span>
#          <div class="details-button-22 sub-swo-cta">
#           Shop Halloween Décor
#          </div>
#         </a>
#        </div>
#       </div>
#       <div class="scroll bopis-utility-menu ca-subswo" style="display:none;">
#        <div class="sub-swo-banner-wrapper">
#         <div class="sub-swo-banner-desktop">
#          <span class="sub-swo-main" style="font-size: 1.4em;">
#           Serve up snacks &amp; screams!
#          </span>
#          <a class="details-button-22 sub-swo-cta" href="https://www.partycity.com/halloween-decorations" rel="nofollow">
#           Shop Halloween Décor
#          </a>
#         </div>
#         <a class="sub-swo-banner-mobile" href="https://www.partycity.com/halloween-decorations" rel="nofollow">
#          <span class="sub-swo-main" style="font-size: 1.2em;">
#           Serve up snacks &amp; screams!
#          </span>
#          <div class="details-button-22 sub-swo-cta">
#           Shop Halloween Décor
#          </div>
#         </a>
#        </div>
#       </div>
#       <style>
#        .sub-swo-cta {
#         display: inline-block;
#         font-weight: 400;
#         font-size: 1em;
#         font-family: FuturaPT-Heavy !important;
#         cursor: pointer;
#         text-decoration: underline;
#         color: #000;
#         margin-left: 3px !important;
#     }
#
#     .sub-swo-banner-desktop,
#     .sub-swo-banner-mobile {
#         margin:0;
#         padding:0;
#         font-weight: 400;
#         font-family: FuturaPT-Heavy !important;
#     }
#
#     .sub-swo-banner-desktop > span,
#     .sub-swo-banner-mobile > span {
#         font-family: inherit;
#         font-size: inherit;
#     }
#
#     .o_main-header section.m_utility-navigation.desktop{
#         display:block
#     }
#
#
#   span.arrow,span.pc-arrow{
#       display: block;
#       position: relative;
#   }
#
#   span.arrow:before,
#   span.arrow:after,
#   span.pc-arrow:before,
#   span.pc-arrow:after{
#       content:"";
#       width: 3px;
#       height: 12px;
#       background-color: #000;
#       transition:all 0.3s ease-in-out;
#       position:absolute;
#       top:-10px;
#       left:50%;
#       transform:translate(-50%, -50%);
#   }
#
#   span.arrow:before,
#   span.pc-arrow:before{
#       transform:translateY(-15%) translateX(-50%) rotate(-45deg);
#   }
#
#
#   span.arrow:after,
#   span.pc-arrow:after{
#       transform:translateY(50%) translateX(-50%) rotate(45deg);
#   }
#
#
#   span.arrow.back,
#   span.pc-arrow.back{
#       transform:rotate(180deg);
#   }
#   /*
#   ul.recent-carousel.slick-initialized .slick-slide{
#       display:block;
#   }
#
#   ul.recent-carousel{
#       display: flex;
#       justify-content: space-between;
#       flex-wrap: wrap;
#   }
#
#   ul.recent-carousel li{
#       width:100%;
#   }
#
#   ul.recent-carousel li picture,
#   ul.recent-carousel li img{
#       width:100%;
#       max-width:100%;
#   }
#
#   ul.recent-carousel a.thumb-link{
#       font-size:1.3em;
#       color:#000;
#   }
#
#   ul.recent-carousel div.price-container{
#       font-size:1.2em;
#       margin-top:0.5em;
#       display:block
#   }
#
#   @media all and (min-width:700px) {
#       ul.recent-carousel ul{
#           display:flex;
#           flex-wrap:wrap;
#           justify-content:space-between;
#       }
#       ul.recent-carousel li{
#           width:24% !important;
#       }
#   }
#   */
#
#   ul.recent-carousel li:nth-child(n+5){
#       display:none;
#   }
#
#   div.o_call-to-action picture, div.o_image-block picture{
#       width:100%;
#   }
#
#   div.o_call-to-action picture img, div.o_image-block picture img{
#       width:100%;
#   }
#
#   .o_category-list-block .o_image-block:before{
#       content:" " !important;
#       padding-top:100%;
#   }
#
#   div.o_category-list-block div.o_image-block img{
#       position:absolute;
#       top:50%;
#       left:50%;
#       -webkit-transform:translate(-50%, -50%);
#       -ms-transform:translate(-50%, -50%);
#           transform:translate(-50%, -50%);
#       height:100%;
#       width:auto;
#   }
#       </style>
#       <style>
#        /* The Modal (background) */
# .custom-modal {
#     position: fixed; /* Stay in place */
#     z-index: 1; /* Sit on top */
#     left: 0;
#     top: 0;
# 	bottom:0;
# 	right: 0;
#     width: 100%; /* Full width */
#     height: 100%; /* Full height */
#     overflow: auto; /* Enable scroll if needed */
#     background-color: rgb(0,0,0); /* Fallback color */
#     background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
# }
#
# /* Modal Content/Box */
# ...
# window.SitePreferences = {"LISTING_INFINITE_SCROLL":true,"LISTING_REFINE_SORT":true,"STORE_PICKUP":true,"COOKIE_HINT":false,"CHECK_TLS":false,"UPS_SHIP_FROM_POSTALCODE":"60563","GEO_COUPON_ENABLED":true,"BROWSERCOKKIE_ENABLE":true,"ADDRESSCOMPLETE_GOOGLE_KEY":"AIzaSyAz76QYTPOvEhItgoJCgQ_3RVM4xkgmWsQ","ADDRESSCOMPLETE_GOOGLE_ENABLED":true,"RECAPTCHA_TEXT":null,"GEO_COSTUME_ENABLED":true,"INCREASINGLY_ENABLED":true};
# //PREVAIL-Window Properties
# window.isAVSEnabled = true;
# }());
# </script>
# <script type="text/javascript">
#  (function(){
# window.SessionAttributes = {"SHOW_CAPTCHA":null};
# window.User = {"zip":null,"storeId":null};
# }());
# </script>
# <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/lib/jquery/jquery-2.1.1.min.js" type="text/javascript">
# </script>
# <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/js/lazy-load.js">
# </script>
# <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/lib/jquery/jquery.validate.min.js" type="text/javascript">
# </script>
# <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/lib/jquery/ui/jquery-ui.min.js" type="text/javascript">
# </script>
# <script src="https://code.jquery.com/jquery-migrate-1.4.1.min.js">
# </script>
# <script src="https://www.partycity.com/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/js/allinone.js" type="text/javascript">
# </script>
# <script>
#  pageContext = {"title":"Search Results","type":"search","ns":"search"};
# </script>
# <script>
#  var meta = "";
# var keywords = "";
# </script>
# <script src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/js/jquery.smartbanner.js">
# </script>
# <script>
#  $(function() {
# if (!navigator.userAgent.match(/Android.+Version\/\d+\.\d+.*Chrome/)) {
# $.smartbanner({ daysHidden: 0, daysReminder: 0, title:'Party City' });
# }
# });
# </script>
# <script type="text/javascript">
#  /* First CSS File */
# var giftofspeed = document.createElement('link');
# giftofspeed.rel = 'stylesheet';
# giftofspeed.href = '/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/css/jquery.smartbanner.css';
# giftofspeed.type = 'text/css';
# var godefer = document.getElementsByTagName('link')[0];
# godefer.parentNode.insertBefore(giftofspeed, godefer);
# </script>
# <div class="content-asset">
#  <style type="text/css">
#   .embeddedServiceHelpButton {
# 	    z-index: 9;
# 	}
# 	.embeddedServiceHelpButton .helpButton{
# 	    display: block;
# 	    background-color: transparent;
# 	    font-weight: 700;
# 	    border: 0;
# 	    font-size: 14px;
# 	    font-family: Arial;
# 	    opacity: 1;
# 	    width: 38px;
# 	    height: 140px;
# 	    z-index: 9;
# 	    cursor: pointer;
# 	    text-decoration: none;
# 	    -webkit-backface-visibility: hidden;
# 	    backface-visibility: hidden;
# 	    transition: all .5s ease;
# 	    -moz-transition: all .5s ease;
# 	    -webkit-transition: all .5s ease;
# 	    -o-transition: all .5s ease;
# 	    right: 4px;
# 	    padding: 0;
# 	    top: 260px;
# 	    color: #000000;
# 	    text-transform: uppercase;
# 	    border-radius: 0;
# 	    box-shadow: none;
# 	}
#
# 	.embeddedServiceHelpButton .helpButton:hover {
# 	    -ms-transform: scale(1.02) translateX(-5px);
# 	    -webkit-transform: translateX(-5px);
# 	    -moz-transform: translateX(-5px);
# 	}
# 	.embeddedServiceHelpButton .helpButton .uiButton{
# 	    background-color: transparent;
# 	}
# 	.embeddedServiceHelpButton .helpButton .uiButton {
# 	    width: 100%;
# 	    height: 100%;
# 	    color: #000000;
# 	    text-transform: uppercase;
# 	    border-radius: 0;
# 	    box-shadow: none;
# 	    padding: 0;
# 	    min-width: auto;
# 	}
# 	.embeddedServiceHelpButton .uiButton .helpButtonLabel {
# 	    width: 100%;
# 	    height: 100%;
# 	}
# 	.embeddedServiceHelpButton .uiButton .helpButtonLabel .message{
# 	    width: 100%;
# 	    height: 100%;
# 	}
# 	.embeddedServiceHelpButton .helpButton .uiButton img{
# 		max-width: 100%;
# 		max-height: 100%;
# 		height: 100%;
# 	}
# 	.embeddedServiceHelpButton .helpButton .uiButton:focus {
# 	    outline: none;
# 	}
#
# 	.embeddedServiceHelpButton .embeddedServiceIcon {
# 	    display: none !important;
# 	}
# 	.embeddedServiceSidebarFormField .uiInput {
# 		font-size: 16px;
# 	}
# 	.embeddedServiceSidebarFormField .uiInput  input[type=text] {
# 		border-radius: 4px;
# 		line-height: 30px;
# 		font-size: 14px;
# 		font-family: "Futura",sans-serif;
# 	}
# 	input[type=text]:not(.search) {
#              height: 44px;
#          }
# 	@media only screen and (min-width: 48em){
# 	    .embeddedServiceHelpButton .helpButton .uiButton:hover::before, .embeddedServiceHelpButton .helpButton .uiButton:focus::before{
# 	        border-radius: 0;
# 	    background: transparent;
# 	    }
#
# 	}
#
# 	@media screen and (max-width: 767px) {
# 	    .embeddedServiceHelpButton .helpButton{
# 	       font-weight: 600;
# 	       font-size: 13px;
# 	       height: 116px;
# 	       width: 30px;
# 	    }
# 	    .embeddedServiceHelpButton .assistiveText {
# 	        font-weight: 600;
# 	        font-size: 13px;
# 	    }
# 	}
#  </style>
#  <script src="https://service.force.com/embeddedservice/5.0/esw.min.js" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   var initESW = function(gslbBaseURL) {
# 	embedded_svc.settings.displayHelpButton = true; //Or false
# 	embedded_svc.settings.language = ''; //For example, enter 'en' or 'en-US'
#
# 	embedded_svc.settings.defaultMinimizedText = '<img class="active" data-text="Chat with an Expert" src="https://www.partycity.com/on/demandware.static/-/Library-Sites-partycity-shared-content2/default/dw3078a0ca/svg/LiveChat.svg"/>'; //(Defaults to Chat with an Expert)
# 	embedded_svc.settings.disabledMinimizedText = '<img class="active" src="https://www.partycity.com/on/demandware.static/-/Library-Sites-partycity-shared-content2/default/dw3078a0ca/svg/LiveChat.svg"/>'; //(Defaults to Agent Offline)
#
# 	embedded_svc.settings.loadingText = '<img class="in-active" src="https://www.partycity.com/on/demandware.static/-/Library-Sites-partycity-shared-content2/default/dw43a60773/svg/LiveChat-gray.svg"/>'; //(Defaults to Loading)
# 	//embedded_svc.settings.storageDomain = 'yourdomain.com'; //(Sets the domain for your deployment so that visitors can navigate subdomains during a chat session)
#
# 	// Settings for Chat
# 	//embedded_svc.settings.directToButtonRouting = function(prechatFormData) {
# 	// Dynamically changes the button ID based on what the visitor enters in the pre-chat form.
# 	// Returns a valid button ID.
# 	//};
# 	//embedded_svc.settings.prepopulatedPrechatFields = {}; //Sets the auto-population of pre-chat form fields
# 	//embedded_svc.settings.fallbackRouting = []; //An array of button IDs, user IDs, or userId_buttonId
# 	embedded_svc.settings.offlineSupportMinimizedText = '<span class="offline" style="display:none">Contact Us</span>'; //(Defaults to Contact Us)
#
# 	embedded_svc.settings.enabledFeatures = ['LiveAgent'];
# 	embedded_svc.settings.entryFeature = 'LiveAgent';
#
# 	embedded_svc.init(
# 	'https://na51.salesforce.com',
# 	'https://partycityliveagent.force.com',
# 	gslbBaseURL,
# 	'00Dd0000000eWsh',
# 	'Party_City_Chat_Support',
# 	{
# 	baseLiveAgentContentURL: 'https://c.la3-c2-phx.salesforceliveagent.com/content',
# 	deploymentId: '5720V000000wk6R',
# 	buttonId: '5730V000001HirW',
# 	baseLiveAgentURL: 'https://d.la3-c2-phx.salesforceliveagent.com/chat',
# 	eswLiveAgentDevName: 'EmbeddedServiceLiveAgent_Parent04I0V000000TN1tUAG_16d022c584a',
# 	isOfflineSupportEnabled: true
# 	}
# 	);
# 	};
#
# 	if (!window.embedded_svc) {
# 	var s = document.createElement('script');
# 	s.setAttribute('src', 'https://cs18.salesforce.com/embeddedservice/5.0/esw.min.js');
# 	s.onload = function() {
# 	initESW(null);
# 	};
# 	document.body.appendChild(s);
# 	} else {
# 	initESW('https://service.force.com');
# 	}
#  </script>
#  <script>
#   setTimeout(function(){
# 	    if ($('.embeddedServiceHelpButton').find('.offline').length > 0 || document.cookie.indexOf('geo_coupon=') >= 0 ) {
# 	        $('.embeddedServiceHelpButton').hide();
# 	    }
# 	    $('.embeddedServiceHelpButton .message img').on('click', function(){
# 	        $(".modalContainer .message").load(function(){
# 	            $('.modalContainer .message').text($('.embeddedServiceHelpButton .message img').data('text'));
# 	         });
# 	    });
#
# 	 }, 10000);
#  </script>
# </div>
# <script type="text/javascript">
#  var utag_data = {
#   "page_name": "Search Results",
#   "page_type": "Search Results",
#   "page_context_type": "search",
#   "page_context_title": "search results",
#   "site_currency": "USD",
#   "customer_ip": "198.214.83.46",
#   "customer_geo_coupon": "false",
#   "jsession_id": "ZOY3V_zqsNSYeeFlEBCNPNxX3kL8ShAaN4U=",
#   "site_region": "us",
#   "site_name": "PCUSHH",
#   "user_agent": "python-requests/2.22.0",
#   "site_form_factor": "Desktop",
#   "kiosk_id": "",
#   "jvm": "production-web-partycity.demandware.net",
#   "user_anonymous": "true",
#   "user_authenticated": "false",
#   "user_registered": "false",
#   "customer_id": "adN6HsXDb2lDQZaMK2vZr2HXa1",
#   "search_results": "92",
#   "search_term": "zombie costumes",
#   "nav_level_1": "Home",
#   "nav_level_2": "Search Term:zombie costumes",
#   "cart_total_value": "0",
#   "sort_by": "",
#   "page_id": "Search  zombie costumes"
# };
# </script>
# <script src="/on/demandware.static/-/Library-Sites-partycity-shared-content2/en_US/v1571180420581/tealium/tag_mgmt.js">
# </script>
# <script type="text/javascript">
#  //PRTY-747: initializeAnaltytics call not happening
# 	  tag_mgmt.initializeAnalytics();
# </script>
# <script>
#  (function(d, w, s) {
#   var f = w.fanplayr = w.fanplayr || { _i:[] };
#   f.custom = f.custom || {};
#   var c = f.custom;
#   var fd = JSON.parse(decodeURIComponent("%7B%22mv%22%3A%2219.2%22%2C%22products%22%3A%5B%5D%2C%22subTotal%22%3A0%2C%22total%22%3A0%2C%22discount%22%3A%220.00%22%2C%22discountCode%22%3A%22%22%2C%22currency%22%3A%22USD%22%2C%22accountKey%22%3A%22a20d4e1860ceaee4ff6573b00a486287%22%2C%22pageType%22%3A%22cat%22%2C%22categoryId%22%3A%22%22%2C%22categoryName%22%3A%22%22%2C%22productId%22%3A%22%22%2C%22productName%22%3A%22%22%2C%22productSku%22%3A%22%22%2C%22productPrice%22%3A0%2C%22productUrl%22%3A%22%22%2C%22productImage%22%3A%22%22%2C%22lineItemCount%22%3A0%2C%22numItems%22%3A0%2C%22applyToCartUrl%22%3A%22https%3A%2F%2Fwww.partycity.com%2Fon%2Fdemandware.store%2FSites-partycity_us2-Site%2Fen_US%2FFanplayr-Apply%3Fcode%3D%25c%22%2C%22sessionOfferUrl%22%3A%22https%3A%2F%2Fwww.partycity.com%2Fon%2Fdemandware.store%2FSites-partycity_us2-Site%2Fen_US%2FFanplayr-Session%3Fcode%3D%25c%22%7D"));
#   f._i.push({
#     version: 3,
#     accountKey: c.accountKey || fd.accountKey,
#     applyToCartUrl: c.applyToCartUrl || fd.applyToCartUrl,
#     sessionOfferUrl: c.sessionOfferUrl || fd.sessionOfferUrl,
#     storeDomain: c.storeDomain || fd.storeDomain || '',
#     data: fd
#   });
#   var js = d.createElement(s);
#   var fjs = d.getElementsByTagName(s)[0];
#   js.async = true;
#   var customLoader = 'https://cdn.fanplayr.com/customers/custom-loader/partycity/loader.js';
#   if (customLoader && customLoader !== 'null' && customLoader !== '') {
# 	  js.src = customLoader;
#   } else {
#     js.src = 'https://cdn.fanplayr.com/client/production/loader.js';
#   }
#   fjs.parentNode.insertBefore(js, fjs);
# })(document, window, 'script');
# </script>
# <script>
#  if ('serviceWorker' in navigator) {
# // Path to service worker at root of your domain.
# var swPath = "/serviceworker";
# // Add current date to url to help ensure service worker is refreshed
# // at least every 24 hours.
# var swCacheBust = new Date().toISOString().substr(0, 10);
# var swUrl = swPath + "?c=" + swCacheBust;
# // Note: Replace PATH_TO_SERVICE_WORKER with correct path on your server.
# navigator.serviceWorker.register(swUrl, {
# // Force service worker to load in root scope.
# scope: "/",
# // Help keep imports inside service worker up to date
# updateViaCache: "none"
# }).then(function() {
# window.fanplayrServiceWorker = true;
# }).catch((error) => {
# // registration failed
# console.log('Service Worker Registration failed. ' + error);
# });
# }
# </script>
# <script type="text/javascript">
#  //<!--
# /* <![CDATA[ */
# function trackPage() {
#     try{
#         var trackingUrl = "https://www.partycity.com/on/demandware.store/Sites-partycity_us2-Site/en_US/__Analytics-Start";
#         var dwAnalytics = dw.__dwAnalytics.getTracker(trackingUrl);
#         if (typeof dw.ac == "undefined") {
#             dwAnalytics.trackPageView();
#         } else {
#             dw.ac.setDWAnalytics(dwAnalytics);
#         }
#     }catch(err) {};
# }
# /* ]]> */
# // -->
# </script>
# <script async="async" onload="trackPage()" src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/internal/jscript/dwanalytics-18.3.js" type="text/javascript">
# </script>
# <script async="async" src="/on/demandware.static/Sites-partycity_us2-Site/-/en_US/v1571180420581/internal/jscript/dwac-18.10.4.js" type="text/javascript">
# </script>
# <script async="async" src="https://cdn.cquotient.com/js/v2/gretel.min.js" type="text/javascript">
# </script>

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="o_product-tile")

# %%
for result in results:

    try:

        title = result.find('span', class_="product-title").text

        price = result.find('div',class_="price-container").text

        url = result.a['href']

        image = result.img['data-src']
        
#         seller = result.find('p', {'data-test-info-type' :'brandName'}).text


        if (title):
            print('-------------')
#             print(f"Seller: {seller}")
            print(f"Product Name: {title}")
            print(f"Product URL: {url}")
            print(f"Product Image URL: {image}")
            print(f"Price: {price}")
            
    except AttributeError as e:
        print(e)
# Out:
# -------------
# Product Name: Girls Prom Corpse Costume
# Product URL: https://www.partycity.com/girls-prom-corpse-costume-P536388.html?dwvar_P536388_size=XL&cgid=undefined
# Product Image URL: https://partycity5.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P536388_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Boys Creepy Zombie Costume
# Product URL: https://www.partycity.com/boys-creepy-zombie-costume-P687345.html?dwvar_P687345_size=M&cgid=undefined
# Product Image URL: https://partycity3.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P687345_full
# Price:
#
# $34.99
#
#
# -------------
# Product Name: Child Zombie Ride-On Costume
# Product URL: https://www.partycity.com/child-zombie-ride-on-costume-P793238.html?dwvar_P793238_size=Standard%20Size&cgid=undefined
# Product Image URL: https://partycity6.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P793238_full
# Price:
#
# $39.99
#
#
# -------------
# Product Name: Girls Addison Costume - Z-O-M-B-I-E-S
# Product URL: https://www.partycity.com/girls-addison-costume---z-o-m-b-i-e-s-P793229.html?dwvar_P793229_size=S&cgid=undefined
# Product Image URL: https://partycity2.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P793229_full
# Price:
#
# $25.99
#
#
# -------------
# Product Name: Boys Soccer Player Zombie Costume
# Product URL: https://www.partycity.com/boys-soccer-player-zombie-costume-P796032.html?dwvar_P796032_size=S&cgid=undefined
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P796032_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Boys Quarantine Zombie Costume
# Product URL: https://www.partycity.com/boys-quarantine-zombie-costume-P792468.html?dwvar_P792468_size=M&cgid=undefined
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P792468_full
# Price:
#
# $16.99
#
#
# -------------
# Product Name: Girls Graveyard Bride Costume
# Product URL: https://www.partycity.com/girls-graveyard-bride-costume-P536420.html?dwvar_P536420_size=S&cgid=undefined
# Product Image URL: https://partycity6.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P536420_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Boys Zombie Football Player Costume
# Product URL: https://www.partycity.com/boys-zombie-football-player-costume-P800644.html?dwvar_P800644_size=S&cgid=undefined
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P800644_full
# Price:
#
# $19.99
#
#
# -------------
# Product Name: Adult Zombie Ride-On Costume
# Product URL: https://www.partycity.com/adult-zombie-ride-on-costume-P793463.html?dwvar_P793463_size=Standard%20Size&cgid=undefined
# Product Image URL: https://partycity4.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P793463_full
# Price:
#
# $49.99
#
#
# -------------
# Product Name: Girls Undead Walker Zombie Costume
# Product URL: https://www.partycity.com/girls-undead-walker-zombie-costume-P750974.html?dwvar_P750974_size=S&cgid=undefined
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P750974_full
# Price:
#
# $24.99
#
#
# -------------
# Product Name: Adult Homecoming Corpse Costume
# Product URL: https://www.partycity.com/adult-homecoming-corpse-costume-P628400.html?dwvar_P628400_size=S&cgid=undefined
# Product Image URL: https://partycity4.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P628400_full&$hide_Promotions-SALE=0
# Price:
#
# Now
# $29.99
#
#
# Was:$39.99
#
#
# -------------
# Product Name: Deluxe Zombie Makeup Kit
# Product URL: https://www.partycity.com/deluxe-zombie-makeup-kit-447582.html
# Product Image URL: https://partycity6.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/447582_full&$hide_Feature-Video=0
# Price:
#
# $4.99
#
#
# -------------
# Product Name: Girls Crypt Bride Costume
# Product URL: https://www.partycity.com/girls-crypt-bride-costume-P789253.html?dwvar_P789253_size=S&cgid=undefined
# Product Image URL: https://partycity6.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P789253_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Boys Dr. Zombie Costume
# Product URL: https://www.partycity.com/boys-dr.-zombie-costume-P789199.html?dwvar_P789199_size=S&cgid=undefined
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P789199_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Adult Creepy Zombie Costume
# Product URL: https://www.partycity.com/adult-creepy-zombie-costume-P687348.html?dwvar_P687348_size=Standard%20Size&cgid=undefined
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P687348_full
# Price:
#
# $39.99
#
#
# -------------
# Product Name: Zombie Gray Cream Makeup 1oz
# Product URL: https://www.partycity.com/zombie-gray-cream-makeup-1oz-445013.html
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/445013_full
# Price:
#
# $1.99
#
#
# -------------
# Product Name: Girls Ghostly Zombie Costume
# Product URL: https://www.partycity.com/girls-ghostly-zombie-costume-P789680.html?dwvar_P789680_size=S&cgid=undefined
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P789680_full
# Price:
#
# $9.99
#
#
# -------------
# Product Name: Adult Zombie Prom Queen Costume
# Product URL: https://www.partycity.com/adult-zombie-prom-queen-costume-P628297.html?dwvar_P628297_size=Adult%20Small&cgid=undefined
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P628297_full
# Price:
#
# $39.99
#
#
# -------------
# Product Name: Womens Zom-Bee Costume
# Product URL: https://www.partycity.com/womens-zom-bee-costume-P789167.html?dwvar_P789167_size=S&cgid=undefined
# Product Image URL: https://partycity5.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P789167_full
# Price:
#
# $36.99
#
#
# -------------
# Product Name: Girls Prima Zomberina Costume
# Product URL: https://www.partycity.com/girls-prima-zomberina-costume-P789249.html?dwvar_P789249_size=S&cgid=undefined
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P789249_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Adult Haunted Pirate Wench Costume
# Product URL: https://www.partycity.com/adult-haunted-pirate-wench-costume-P687014.html?dwvar_P687014_size=M&cgid=undefined
# Product Image URL: https://partycity3.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P687014_full
# Price:
#
# $49.99
#
#
# -------------
# Product Name: Barbed Wire Baseball Bat
# Product URL: https://www.partycity.com/barbed-wire-baseball-bat-686511.html
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/686511_full
# Price:
#
# $9.99
#
#
# -------------
# Product Name: Boys Death Warrior Costume
# Product URL: https://www.partycity.com/boys-death-warrior-costume-P591157.html?dwvar_P591157_size=M&cgid=undefined
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P591157_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Boys Caged Zombie Costume
# Product URL: https://www.partycity.com/boys-caged-zombie-costume-P792458.html?dwvar_P792458_size=M&cgid=undefined
# Product Image URL: https://partycity2.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P792458_full
# Price:
#
# $24.99
#
#
# -------------
# Product Name: Adult Ghost Bride Costume
# Product URL: https://www.partycity.com/adult-ghost-bride-costume-P686991.html?dwvar_P686991_size=Standard%20Size&cgid=undefined
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P686991_full
# Price:
#
# $54.99
#
#
# -------------
# Product Name: Girls Haunted Pirate Costume
# Product URL: https://www.partycity.com/girls-haunted-pirate-costume-P628408.html?dwvar_P628408_size=M&cgid=undefined
# Product Image URL: https://partycity6.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P628408_full
# Price:
#
# $34.99
#
#
# -------------
# Product Name: Girls Zom-Bee Costume
# Product URL: https://www.partycity.com/girls-zom-bee-costume-P792522.html?dwvar_P792522_size=S&cgid=undefined
# Product Image URL: https://partycity5.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P792522_full
# Price:
#
# $24.99
#
#
# -------------
# Product Name: Boys Punk Zombie Costume
# Product URL: https://www.partycity.com/boys-punk-zombie-costume-P355222.html?dwvar_P355222_size=M&cgid=undefined
# Product Image URL: https://partycity5.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P355222_full
# Price:
#
# $24.99
#
#
# -------------
# Product Name: Adult Haunted Pirate Wench Costume Plus Size
# Product URL: https://www.partycity.com/adult-haunted-pirate-wench-costume-plus-size-P687013.html?dwvar_P687013_size=Plus&cgid=undefined
# Product Image URL: https://partycity.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P687013_full
# Price:
#
# $49.99
#
#
# -------------
# Product Name: Rob Zombie Michael Myers Mask
# Product URL: https://www.partycity.com/rob-zombie-michael-myers-mask-544999.html
# Product Image URL: https://partycity5.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/544999_full
# Price:
#
# $29.99
#
#
# -------------
# Product Name: Child Zombie Gown
# Product URL: https://www.partycity.com/child-zombie-gown-686509.html
# Product Image URL: https://partycity6.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/686509_full
# Price:
#
# $19.99
#
#
# -------------
# Product Name: Zombie Rot Wound Prosthetics 4ct- Tinsley Transfers
# Product URL: https://www.partycity.com/zombie-rot-wound-prosthetics-4ct--tinsley-transfers-592377.html
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/592377_full&$hide_Feature-Video=0
# Price:
#
# $12.99
#
#
# -------------
# Product Name: Boys Zombie Slayer Costume
# Product URL: https://www.partycity.com/boys-zombie-slayer-costume-P751106.html?dwvar_P751106_size=M&cgid=undefined
# Product Image URL: https://partycity2.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P751106_full
# Price:
#
# $49.99
#
#
# -------------
# Product Name: Sexy Zombie Dress
# Product URL: https://www.partycity.com/sexy-zombie-dress-686508.html
# Product Image URL: https://partycity6.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/686508_full
# Price:
#
# $34.99
#
#
# -------------
# Product Name: Adult Complete Zombie Costume Plus Size
# Product URL: https://www.partycity.com/adult-complete-zombie-costume-plus-size-P157883.html?dwvar_P157883_size=Plus&cgid=undefined
# Product Image URL: https://partycity1.scene7.com/is/image/PartyCity/_mobile_?$_600x400_$&$product=PartyCity/P157883_full
# Price:
#
# $39.99
#
#
# -------------
# Product Name: Negan's Bat - The Walking Dead
# Product URL: https://www.partycity.com/negans-bat---the-walking-dead-756762.html
# Product Image URL: https://partycity2.scene7.com/is/image/PartyCity/_sq_?$_500x500_$&$product=PartyCity/756762_full
# Price:
#
# $29.99
